# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
# Defining Functions

def click_to_pk_page_redux():
    list_more_links = driver.find_elements(By.PARTIAL_LINK_TEXT,'more')
    page_exists = False
    for link in list_more_links:
        if len(link.text.split(' ')) == 2:
            link.click() # Temporary, need to identify by new thing
            page_exists = True
            return page_exists
    return page_exists
    
def find_general_info(soup):
    #title = soup.find('h1',"TitleHeader__TitleText-sc-1wu6n3d-0 dxSWFG").string
    title = soup.find('h1')
    title =['Title',title.text]
    
    #year_of_release = ''
    #try: 
    #    year_of_release = soup.find('a','ipc-link ipc-link--baseAlt ipc-link--inherit-color TitleBlockMetaData__StyledTextLink-sc-12ein40-1 rgaOW').string
    #except:
    #    year_of_release = soup.find('a',"ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link")
    #year_of_release = ['Year',year_of_release]
    
    imdb_rating = ''
    try:
        imdb_rating = soup.find('span',"AggregateRatingButton__RatingScore-sc-1ll29m0-1 iTLWoV").string
        imdb_rating = ['IMDB_Rating',imdb_rating]
    except:
        imdb_rating = ['IMDB_Rating',imdb_rating]
    
    description = ''
    try:
        description = soup.find('span',"GenresAndPlot__TextContainerBreakpointL-cum89p-1 gwuUFD").string
        description = ['Movie_Description',description]
    except:
        try: 
            description = soup.find(class_ = 'GenresAndPlot__TextContainerBreakpointXL-cum89p-2 gCtawA')
            description = ['Movie_Description',description]
        except:
            description = ['Movie_Description',description]
    
    release_date = ''
    try:
        temp = soup.find_all('ul',class_='ipc-metadata-list ipc-metadata-list--dividers-all ipc-metadata-list--base')
        release_date = temp[1].find(class_='ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link').string
        release_date = release_date.split('(')[0]
        release_date = ['Date_of_Release',release_date]
    except:
        try:
            temp = driver.find_element(By.PARTIAL_LINK_TEXT,'(United States)')
            release_date = temp.text.split('(')[0]
            release_date = ['Date_of_Release',release_date]
        except:
            release_date = ['Date_of_Release',release_date]
    
    return [title,imdb_rating,description,release_date]

def find_plot_keywords():
    if click_to_pk_page_redux() == True:
        soup = bs(driver.page_source,'html.parser')
        plot_keywords = []
        rows = soup.find('tbody').find_all('tr')
        for row in rows:
            two_cols = row.find_all(class_='soda sodavote')
            for col in two_cols:
                sub_col = col.find(class_='interesting-count-text').a.string[1:-1]
                val = col['data-item-keyword']
                plot_keywords.append([val,sub_col])
        top_ten = plot_keywords[0:10]
        top_ten_list = []
        for item in top_ten:
            top_ten_list.append(item[0])
        return ['Plot_Keywords',top_ten_list]
    else:
        return ['Plot_Keywords',['none']]
    
def click_next():
    htmlelement= driver.find_element(By.TAG_NAME,'html')
    htmlelement.send_keys(Keys.HOME)
    desc = driver.find_element(By.CLASS_NAME,'desc')
    next_link = desc.find_element(By.PARTIAL_LINK_TEXT,'Next')
    next_link.click()
    return

def get_page_count():
    desc = driver.find_element(By.CLASS_NAME,'desc').text
    if '-' in desc:
        split = desc.split(' ')
        split_split = split[0].split('-')
        for i in range(len(split_split)):
            split_split[i] = split_split[i].replace(',','')
        page_range = int(split_split[-1])-int(split_split[0])+1
        return page_range
    elif 'to' in desc:
        split = desc.split(' ')
        for i in range(len(split)):
            split[i] = split[i].replace(',','')
        page_range = int(split[2])-int(split[0])+1
    else:
        page_range = int(desc.split(' ')[0])
    return page_range
    
def get_total_count():
    desc = driver.find_element(By.CLASS_NAME,'desc').text
    split = desc.split(' ')
    if 'of' in split:
        number = split[split.index('of')+1]    
    else:
        number = split[0]
    number = number.replace(',','')
    #if ',' in number:
    #    number = int(number.replace(',',''))
    #else:
    #    number = int(number)
    return int(number)
### SOMETIMES IT's TO AND SOMETIMES IT's -.... figure out better way to get the numbers out

def get_movie_info_modified():
    soup = bs(driver.page_source,'html.parser')
    movie_data = find_general_info(soup)
    boxoffice = find_boxoffice_modified(soup)
    
    for item in boxoffice:
        movie_data.append(item)
    
    values = []
    for item in movie_data:
        values.append(item)    
    return(values)

def click_to_movie_page_modified(i):
    area = driver.find_element(By.CLASS_NAME, 'lister-list')
    rows = area.find_elements(By.CLASS_NAME, 'lister-item-header')
    link_name = rows[i].text.split(' ')[1]
    rows[i].find_element(By.PARTIAL_LINK_TEXT,link_name).click()
    return

def get_keyword_list():  
    keyword_list = []
    done = False
    while done == False:
        keyword = input('Please enter the plot keyword you would like movie data for.\n\
If searching by multiple keywords at once, separate them with forward-slashes. \nEnter: ')
        split = keyword.split('/')
        for i in range(len(split)):
            if split[i][0] == ' ':
                split[i] = split[i][1:]
        for i in range(len(split)):
            split[i] = split[i].replace(' ','-')
        keyword_list.append(split)
        search = input('Would you like data for another keyword? \nResults are saved\
in separate .csv files for each keyword you input. \nEnter y/n: ')
        if search == 'n':
            done = True
    return keyword_list

def get_keyword_url(keyword):
    if len(keyword) == 1:
        keyword_url = f'https://www.imdb.com/search/keyword/?keywords={keyword[0]}&ref_=kw_ref_typ&sort=moviemeter,asc&mode=detail&page=1&title_type=movie'
        return keyword_url
    elif len(keyword) > 1:
        # alien%2Couter-space%2Cspaceship
        keywords = '%2C'.join(keyword)
        keyword_url = f'https://www.imdb.com/search/keyword/?keywords={keywords}&ref_=kw_ref_key&mode=detail&page=1&title_type=movie&sort=moviemeter,asc'
        return keyword_url
    
def find_boxoffice_modified(soup):
    items = soup.find_all('li','ipc-metadata-list__item BoxOffice__MetaDataListItemBoxOffice-sc-40s2pl-2 gwNUHl')
    possible_items = ['Budget','Gross US & Canada','Opening weekend US & Canada','Gross worldwide']
    values = [['Budget',""],['Gross US & Canada',""],['Opening weekend US & Canada',""],['Gross worldwide',""]]
    for item in items:
        amount = ''
        label = item.find(class_='ipc-metadata-list-item__label').string
        temp = item.find(class_='ipc-metadata-list-item__list-content-item')
        values[possible_items.index(label)][-1] = temp.text
    final_list = []
    for i in range(4):
        final_list.append(values[i])
    return final_list

# %%
val_list = []
keyword_list = get_keyword_list()
driver = webdriver.Chrome()
for keyword in keyword_list: 
    url = get_keyword_url(keyword)
    driver.get(url)
    titles_count = get_total_count()
    if titles_count > 200:
        titles_count = 150
    for j in range(titles_count // 50 + 1):
        for i in range(get_page_count()):
            try:
                click_to_movie_page_modified(i)
            except:
                continue
            movie_info = get_movie_info_modified()
            print(f'got movie info for {movie_info[0][-1]}')
            values = []
            for item in movie_info:
                values.append(item[-1])
            val_list.append(values)
            driver.back()        
        if j == titles_count // 50:
            continue
        else:
            time.sleep(5)
            click_next()
            time.sleep(5)
    # Wasn't remembering columns variable after the try block. Probably a good thing.
    columns = ['Title','IMDB_Rating','Movie_Description','Release_Date', 'Budget',\
              'Gross_US_Canada', 'Opening_Weekend_US_Canada', 'Gross_Worldwide']
    for i in range(len(keyword)):
        keyword[i] = keyword[i].replace('-','_')
    df = pd.DataFrame(val_list)
    df.columns = columns
    df.to_csv(f'keyword_{"_".join(keyword)}.csv')
    print(f'\n\n CSV SUCCESSFULLY CREATED: keyword_{"_".join(keyword)}.csv')
print(f'Grabbed {len(df)} out of {titles_count} samples')
driver.quit()
# Out:
# Please enter the plot keyword you would like movie data for.
# If searching by multiple keywords at once, separate them with forward-slashes.
# Enter: alien
# Would you like data for another keyword?
# Results are savedin separate .csv files for each keyword you input.
# Enter y/n: n
# got movie info for Don't Look Up
# got movie info for Dune
# got movie info for The Suicide Squad
# got movie info for Venom: Let There Be Carnage
# got movie info for Spider-Man: Far from Home
# got movie info for Eternals
# got movie info for Avengers: Endgame
# got movie info for Venom
# got movie info for Avengers: Infinity War
# got movie info for Zack Snyder's Justice League
# got movie info for Captain Marvel
# got movie info for Avatar 2
# got movie info for Guardians of the Galaxy
# got movie info for The Avengers
# got movie info for Thor: Ragnarok
# got movie info for Encounter
# got movie info for Star Wars: Episode IX - The Rise of Skywalker
# got movie info for Avatar
# got movie info for A Quiet Place Part II
# got movie info for Star Wars: Episode IV - A New Hope
# got movie info for The Tomorrow War
# got movie info for Guardians of the Galaxy Vol. 2
# got movie info for E.T. the Extra-Terrestrial
# got movie info for Aliens
# got movie info for Star Wars: Episode VII - The Force Awakens
# got movie info for Chaos Walking
# got movie info for Alien
# got movie info for Rogue One: A Star Wars Story
# got movie info for Star Wars: Episode I - The Phantom Menace
# got movie info for Arrival
# got movie info for Solo: A Star Wars Story
# got movie info for Man of Steel
# got movie info for Independence Day
# got movie info for Star Wars: Episode V - The Empire Strikes Back
# got movie info for A Quiet Place
# got movie info for Space Jam: A New Legacy
# got movie info for Star Wars: Episode VIII - The Last Jedi
# got movie info for Star Wars: Episode II - Attack of the Clones
# got movie info for Sonic the Hedgehog
# got movie info for Justice League
# got movie info for Star Wars: Episode VI - Return of the Jedi
# got movie info for It
# got movie info for Toy Story 4
# got movie info for The Thing
# got movie info for Jupiter Ascending
# got movie info for 2001: A Space Odyssey
# got movie info for Star Trek
# got movie info for The Fifth Element
# got movie info for Star Wars: Episode III - Revenge of the Sith
# got movie info for Batman v Superman: Dawn of Justice
# got movie info for Men in Black
# got movie info for Transformers
# got movie info for Mars Attacks!
# got movie info for The Rocky Horror Picture Show
# got movie info for Galaxy Quest
# got movie info for Bumblebee
# got movie info for Edge of Tomorrow
# got movie info for Toy Story
# got movie info for Prometheus
# got movie info for Starship Troopers
# got movie info for Oblivion
# got movie info for X-Men: Dark Phoenix
# got movie info for TRON: Legacy
# got movie info for Predator
# got movie info for Annihilation
# got movie info for Superman
# got movie info for Alien: Covenant
# got movie info for Ender's Game
# got movie info for Close Encounters of the Third Kind
# got movie info for Lost in Space
# got movie info for Super 8
# got movie info for Star Trek Into Darkness
# got movie info for Valerian and the City of a Thousand Planets
# got movie info for Spaceballs
# got movie info for Star Trek Beyond
# got movie info for Green Lantern
# got movie info for Cloverfield
# got movie info for Stargate
# got movie info for Godzilla: King of the Monsters
# got movie info for Cocoon
# got movie info for Total Recall
# got movie info for District 9
# got movie info for Indiana Jones and the Kingdom of the Crystal Skull
# got movie info for Contact
# got movie info for Life
# got movie info for Transformers: The Last Knight
# got movie info for 10 Cloverfield Lane
# got movie info for Space Jam
# got movie info for Under the Skin
# got movie info for Men in Black: International
# got movie info for Monsters vs. Aliens
# got movie info for War of the Worlds
# got movie info for Dark City
# got movie info for The Predator
# got movie info for Life of Brian
# got movie info for Flash Gordon
# got movie info for The Dead Don't Die
# got movie info for They Live
# got movie info for Home
# got movie info for Toy Story 3
# got movie info for Pacific Rim
# got movie info for Signs
# got movie info for John Carter
# got movie info for The Hitchhiker's Guide to the Galaxy
# got movie info for Battleship
# got movie info for Transformers: Dark of the Moon
# got movie info for Barbarella
# got movie info for Men in Black 3
# got movie info for Little Shop of Horrors
# got movie info for Black Friday
# got movie info for Teenage Mutant Ninja Turtles: Out of the Shadows
# got movie info for Independence Day: Resurgence
# got movie info for The Lego Movie
# got movie info for Toy Story 2
# got movie info for Men in Black II
# got movie info for Stalker
# got movie info for The Day the Earth Stood Still
# got movie info for Cosmic Sin
# got movie info for Alien 3
# got movie info for The Abyss
# got movie info for Fantastic 4: Rise of the Silver Surfer
# got movie info for We Can Be Heroes
# got movie info for Pitch Black
# got movie info for Power Rangers
# got movie info for Happy Feet
# got movie info for Transformers: Age of Extinction
# got movie info for The Thing
# got movie info for The World's End
# got movie info for Megamind
# got movie info for Lilo & Stitch
# got movie info for Masters of the Universe
# got movie info for Knowing
# got movie info for I Am Number Four
# got movie info for Alien: Resurrection
# got movie info for The Faculty
# got movie info for Species
# got movie info for Riddick
# got movie info for Pixels
# got movie info for Howard the Duck
# got movie info for Scary Movie 3
# got movie info for Transformers: Revenge of the Fallen
# got movie info for Zathura: A Space Adventure
# got movie info for Predators
# got movie info for The Fourth Kind
# got movie info for The Holy Mountain
# got movie info for My Stepmother Is an Alien
# got movie info for Outlander
# got movie info for Treasure Planet
# got movie info for Paul
# got movie info for The Iron Giant
# got movie info for Brightburn
# got movie info for Lifeforce
# got movie info for Flight of the Navigator
# got movie info for Dude, Where's My Car?
# got movie info for Color Out of Space
# got movie info for The 5th Wave
# got movie info for The Day the Earth Stood Still
# got movie info for The Last Starfighter
# got movie info for The Flintstones in Viva Rock Vegas
# got movie info for Solaris
# got movie info for Psycho Goreman
# got movie info for Dragonball Evolution
# got movie info for Invasion of the Body Snatchers
# got movie info for Star Trek II: The Wrath of Khan
# got movie info for Battlefield Earth
# got movie info for Superman II
# got movie info for The Darkest Hour
# got movie info for The Invasion
# got movie info for Cowboys & Aliens
# got movie info for Alien vs. Predator
# got movie info for The X Files
# got movie info for Across the Universe
# got movie info for Star Trek: The Motion Picture
# got movie info for Race to Witch Mountain
# got movie info for Predator 2
# got movie info for The Lego Movie 2: The Second Part
# got movie info for The Adventures of Buckaroo Banzai Across the 8th Dimension
# got movie info for Doom
# got movie info for Pacific Rim: Uprising
# got movie info for Heavy Metal
# got movie info for Prey
# got movie info for The Space Between Us
# got movie info for Occupation: Rainfall
# got movie info for Evolution
# got movie info for Pandorum
# got movie info for Star Trek VI: The Undiscovered Country
# got movie info for After Earth
# got movie info for Krull
# got movie info for The Vast of Night
# got movie info for Coneheads
# got movie info for V/H/S
# got movie info for Dark Skies
# got movie info for Jiu Jitsu
# got movie info for The Host
# got movie info for Star Trek IV: The Voyage Home
# got movie info for Supergirl
# got movie info for Star Trek: First Contact
# got movie info for PK
# got movie info for Naked Lunch
# got movie info for Star Trek: Nemesis
# got movie info for The Wraith
# got movie info for Mighty Morphin Power Rangers: The Movie
# got movie info for Skylines
# got movie info for Captive State
# got movie info for Earth Girls Are Easy
# got movie info for Repo Man
# got movie info for Attack the Block
# got movie info for Beyond White Space
# got movie info for A Quiet Place Part III
# got movie info for Dreamcatcher
# got movie info for Critters
# got movie info for Aliens vs. Predator: Requiem
# got movie info for From Beyond
# got movie info for Explorers
# got movie info for The Signal
# got movie info for Star Trek: Insurrection
# got movie info for Killer Klowns from Outer Space
# got movie info for Skyline
# got movie info for *batteries not included
# got movie info for Enemy Mine
# got movie info for The Blob
# got movie info for This Island Earth
# got movie info for Highlander II: The Quickening
# got movie info for Fire in the Sky
# got movie info for Invasion
# got movie info for Mysterious Skin
# got movie info for Sputnik
# got movie info for The War of the Worlds
# got movie info for Beyond Skyline
# got movie info for Midnight Special
# got movie info for Mac and Me
# got movie info for Absolutely Anything
# got movie info for The Watch
# got movie info for Daleks' Invasion Earth 2150 A.D.
# got movie info for The Andromeda Strain
# got movie info for Blue Beetle
# got movie info for The Untamed
# got movie info for Starman
# got movie info for Attraction
# got movie info for Monsters
# got movie info for The Thing from Another World
# got movie info for Phantasm
# got movie info for The Man Who Fell to Earth
# got movie info for K-PAX
# got movie info for Heavy Metal 2000
# got movie info for Rim of the World
# got movie info for Bad Taste
# got movie info for UHF
# got movie info for SLC Punk!
#
#
#  CSV SUCCESSFULLY CREATED: keyword_alien.csv
# Grabbed 249 out of 200 samples
